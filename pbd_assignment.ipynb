# %% [markdown]
#  # Find the total number of patients of each disease (diagnosis) and plot in histogram.
#    # Find the total number of patients of each disease (diagnosis) with respect to the disease state(malignant or benign) and plot in a pie chart.
#    # Find and plot via pia chart the total number of patients of each disease (diagnosis) with respect to the gender(Female, Male)

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("jsrt_metadata.csv")
print("Data Before cleaning")
print("*********************")
print(df.isnull().sum())
print("*********************")
# Out:
# Data Before cleaning
# *********************
# study_id      0
# subtlety     93
# size         93
# age           0
# gender        0
# x            93
# y            93
# state         0
# position     93
# diagnosis    93
# dtype: int64
# *********************

# %%
df['subtlety'].replace(np.nan, df['subtlety'].astype(float).mean(), inplace=True)

df['size'].replace(np.nan, df['size'].astype(float).mean(), inplace=True)

df['x'].replace(np.nan, df['x'].astype(float).mean(), inplace=True)

df['y'].replace(np.nan, df['y'].astype(float).mean(), inplace=True)


df['position'].replace(np.nan, df['position'].value_counts().idxmax(), inplace=True)

df['diagnosis'].replace(np.nan, df['diagnosis'].value_counts().idxmax(), inplace=True)


print("Data after cleaning")
print("*********************")
print(df.isnull().sum())
print("*********************")
# Out:
# Data after cleaning
# *********************
# study_id     0
# subtlety     0
# size         0
# age          0
# gender       0
# x            0
# y            0
# state        0
# position     0
# diagnosis    0
# dtype: int64
# *********************

# %% [markdown]
# # Find the total number of patients of each disease (diagnosis) and plot in histogram.

# %%
import matplotlib as plt
from matplotlib import pyplot
plt.rcParams['axes.facecolor'] = 'grey'
plt.rcParams["figure.figsize"] = (20, 10)
plt.style.use('ggplot')
df['diagnosis'].value_counts() 

plt.pyplot.xlabel("Diagnosis")
plt.pyplot.ylabel("Number of Patients")
plt.pyplot.hist(df['diagnosis'],color = 'pink',edgecolor='white')
# Out:
# (array([167.,  33.,  13.,   5.,   8.,   7.,   3.,   3.,   4.,   4.]),
#  array([ 0. ,  3.1,  6.2,  9.3, 12.4, 15.5, 18.6, 21.7, 24.8, 27.9, 31. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Find the total number of patients of each disease (diagnosis) with respect to the patient gender (Male, Female) and plot in a pie chart.

# %%
for i in list(df['diagnosis'].unique()):
   
    print(df.loc[df['diagnosis'] == i]['state'].value_counts())
# Out:
# non-nodule    93
# malignant     56
# Name: state, dtype: int64
# benign    2
# Name: state, dtype: int64
# benign    2
# Name: state, dtype: int64
# benign    14
# Name: state, dtype: int64
# benign    8
# Name: state, dtype: int64
# malignant    23
# Name: state, dtype: int64
# benign    2
# Name: state, dtype: int64
# benign    4
# Name: state, dtype: int64
# benign    2
# Name: state, dtype: int64
# malignant    7
# Name: state, dtype: int64
# benign    2
# Name: state, dtype: int64
# malignant    2
# Name: state, dtype: int64
# benign    1
# Name: state, dtype: int64
# benign    3
# Name: state, dtype: int64
# malignant    4
# Name: state, dtype: int64
# benign    1
# Name: state, dtype: int64
# benign    4
# Name: state, dtype: int64
# benign    1
# Name: state, dtype: int64
# benign    2
# Name: state, dtype: int64
# malignant    1
# Name: state, dtype: int64
# malignant    1
# Name: state, dtype: int64
# malignant    1
# Name: state, dtype: int64
# benign    1
# Name: state, dtype: int64
# benign    1
# Name: state, dtype: int64
# malignant    1
# Name: state, dtype: int64
# malignant    1
# Name: state, dtype: int64
# benign    2
# Name: state, dtype: int64
# malignant    1
# Name: state, dtype: int64
# benign    1
# Name: state, dtype: int64
# malignant    1
# Name: state, dtype: int64
# benign    1
# Name: state, dtype: int64
# malignant    1
# Name: state, dtype: int64

# %% [markdown]
# # Pie chart

# %%
import matplotlib as plt
from matplotlib import pyplot
plt.rcParams["figure.figsize"] = (20, 5)



for i in list(df['diagnosis'].unique()):
    plt.pyplot.figure()   
    plt.pyplot.pie(df.loc[df['diagnosis'] == i]['state'].value_counts(),
                   labels=list(df.loc[df['diagnosis'] == i]['state'].value_counts().keys())
                   ,colors = ['#ff9999','#66b3ff'],wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' },
                   shadow=True,startangle=90,autopct="%1.1f%%")
    plt.pyplot.legend(title= i)
# Out:
# C:\Users\ABDULL~1\AppData\Local\Temp/ipykernel_7316/207515104.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.pyplot.figure()

# %% [markdown]
#  # Find the total number of patients of each disease (diagnosis) with respect to the patient gender (Male, Female) and plot in a pie chart.

# %%
for i in list(df['diagnosis'].unique()):
  
    print(df.loc[df['diagnosis'] == i]['gender'].value_counts())
# Out:
# Male      75
# Female    74
# Name: gender, dtype: int64
# Female    1
# Male      1
# Name: gender, dtype: int64
# Female    2
# Name: gender, dtype: int64
# Male      9
# Female    5
# Name: gender, dtype: int64
# Male      6
# Female    2
# Name: gender, dtype: int64
# Female    15
# Male       8
# Name: gender, dtype: int64
# Female    2
# Name: gender, dtype: int64
# Female    4
# Name: gender, dtype: int64
# Male      1
# Female    1
# Name: gender, dtype: int64
# Female    4
# Male      3
# Name: gender, dtype: int64
# Female    2
# Name: gender, dtype: int64
# Male    2
# Name: gender, dtype: int64
# Female    1
# Name: gender, dtype: int64
# Male    3
# Name: gender, dtype: int64
# Female    3
# Male      1
# Name: gender, dtype: int64
# Male    1
# Name: gender, dtype: int64
# Female    2
# Male      2
# Name: gender, dtype: int64
# Male    1
# Name: gender, dtype: int64
# Male      1
# Female    1
# Name: gender, dtype: int64
# Male    1
# Name: gender, dtype: int64
# Female    1
# Name: gender, dtype: int64
# Male    1
# Name: gender, dtype: int64
# Male    1
# Name: gender, dtype: int64
# Female    1
# Name: gender, dtype: int64
# Male    1
# Name: gender, dtype: int64
# Female    1
# Name: gender, dtype: int64
# Female    2
# Name: gender, dtype: int64
# Female    1
# Name: gender, dtype: int64
# Female    1
# Name: gender, dtype: int64
# Female    1
# Name: gender, dtype: int64
# Male    1
# Name: gender, dtype: int64
# Female    1
# Name: gender, dtype: int64

# %%
import matplotlib as plt
from matplotlib import pyplot
plt.rcParams["figure.figsize"] = (20, 5)



for i in list(df['diagnosis'].unique()):
    plt.pyplot.figure()   
    plt.pyplot.pie(df.loc[df['diagnosis'] == i]['gender'].value_counts(),
                   labels=list(df.loc[df['diagnosis'] == i]['gender'].value_counts().keys())
                   ,colors = ['#ff9999','#66b3ff'],wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' },
                   shadow=True,startangle=90,autopct="%1.1f%%")
    plt.pyplot.legend(title= i)
# Out:
# C:\Users\ABDULL~1\AppData\Local\Temp/ipykernel_7316/2205028573.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.pyplot.figure()
